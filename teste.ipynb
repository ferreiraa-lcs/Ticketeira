# %%
# Criar pasta do evento com pelo menos 4 informaçôes 

evento = {               #DICIONÁRIO

    "nome" : "Show do Ferrugem",
    "data" : "07/05/2026",
    "preço" : 110.00,
    "ingressos_restantes" : 100,
    "tipo_ingressos" : ["Pista", "VIP", "Camarote"]

}

#print do nome do evento

print (evento["nome"])

#print do preço

print (evento["preço"])

#print mostra o segundo tipo da lista ingressos

print (evento["tipo_ingressos"][1])
# Out:
# Show do Ferrugem
# 110.0
# VIP
